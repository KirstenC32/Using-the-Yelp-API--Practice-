# %%
from yelpapi import YelpAPI
import json
import pandas as pd

# %%
import json
with open('/Users/12103/.secret/yelp_api.json') as f:
    login = json.load(f)
login.keys()
# Out:
# dict_keys(['client-id', 'api-key'])

# %%
# import the YelpAPI Class
from yelpapi import YelpAPI
# Create an instance with your key
yelp_api = YelpAPI(login['api-key'], timeout_s=5.0)
yelp_api

# %%
# use our yelp_api variable's search_query method to perform our API call
search_results = yelp_api.search_query(location='NY, NY',
                                       term='Pizza')
print(type(search_results))
search_results.keys()
# Out:
# <class 'dict'>
# dict_keys(['businesses', 'total', 'region'])

# %%
search_results['total']
# Out:
# 12400

# %%
biz = pd.DataFrame(search_results['businesses'])
biz.head(2)
# Out:
#                        id                           alias  \
# 0  ysqgdbSrezXgVwER2kQWKA             julianas-brooklyn-3
# 1  zj8Lq1T8KIC5zwFief15jg  prince-street-pizza-new-york-2
#
#                   name                                          image_url  \
# 0            Juliana's  https://s3-media2.fl.yelpcdn.com/bphoto/od36nF...
# 1  Prince Street Pizza  https://s3-media1.fl.yelpcdn.com/bphoto/2-U43P...
#
#    is_closed                                                url  review_count  \
# 0      False  https://www.yelp.com/biz/julianas-brooklyn-3?a...          2722
# 1      False  https://www.yelp.com/biz/prince-street-pizza-n...          5124
#
#                                           categories  rating  \
# 0             [{'alias': 'pizza', 'title': 'Pizza'}]     4.5
# 1  [{'alias': 'pizza', 'title': 'Pizza'}, {'alias...     4.5
#
#                                          coordinates        transactions  \
# ...

# %%
# add offset to our original api call
search_results = yelp_api.search_query(location='NY, NY',
                                       term='Pizza',
                                       offset = 20)

# %%
biz20 = pd.DataFrame(search_results['businesses'])
biz20.head(2)
# Out:
#                        id                                alias  \
# 0  LF1QAuvpfX7KGQlg2zMg6Q  johns-of-bleecker-street-new-york-2
# 1  hZBxJfZtDjnMzH_jNFNHRQ         little-pizza-parlor-brooklyn
#
#                         name  \
# 0  John's of Bleecker Street
# 1        Little Pizza Parlor
#
#                                            image_url  is_closed  \
# 0  https://s3-media1.fl.yelpcdn.com/bphoto/r2bmU0...      False
# 1  https://s3-media2.fl.yelpcdn.com/bphoto/99YkIi...      False
#
#                                                  url  review_count  \
# 0  https://www.yelp.com/biz/johns-of-bleecker-str...          2679
# 1  https://www.yelp.com/biz/little-pizza-parlor-b...            63
#
#                                categories  rating  \
# 0  [{'alias': 'pizza', 'title': 'Pizza'}]     4.0
# 1  [{'alias': 'pizza', 'title': 'Pizza'}]     4.5
#
#                                         coordinates        transactions price  \
# ...

# %%
## concatenate the previous results and new results. 
businesses = pd.concat([biz, biz20],
                      ignore_index=True)
display(businesses.head(3), businesses.tail(3))
# Out:
#                        id                           alias  \
# 0  ysqgdbSrezXgVwER2kQWKA             julianas-brooklyn-3
# 1  zj8Lq1T8KIC5zwFief15jg  prince-street-pizza-new-york-2
# 2  WG639VkTjmK5dzydd1BBJA             rubirosa-new-york-2
#
#                   name                                          image_url  \
# 0            Juliana's  https://s3-media2.fl.yelpcdn.com/bphoto/od36nF...
# 1  Prince Street Pizza  https://s3-media1.fl.yelpcdn.com/bphoto/2-U43P...
# 2             Rubirosa  https://s3-media3.fl.yelpcdn.com/bphoto/l0Phrn...
#
#    is_closed                                                url  review_count  \
# 0      False  https://www.yelp.com/biz/julianas-brooklyn-3?a...          2722
# 1      False  https://www.yelp.com/biz/prince-street-pizza-n...          5124
# 2      False  https://www.yelp.com/biz/rubirosa-new-york-2?a...          3226
#
#                                           categories  rating  \
# ...

# %%
# save the results to records-style json file with appropriate name
businesses.to_json("Data/yelp-search-pizza-NY.json", orient='records')

# %%
## concatenate the previous results and new results. 
pizza_businesses = pd.concat([biz, biz20],
                      ignore_index=True)
display(pizza_businesses.head(3), pizza_businesses.tail(3))
